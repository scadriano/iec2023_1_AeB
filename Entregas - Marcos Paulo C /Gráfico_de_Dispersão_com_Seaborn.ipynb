# %% [markdown]
# <a href="https://colab.research.google.com/github/marcospaulo2ufg/iec2023_1_AeB/blob/main/Entregas%20-%20Marcos%20Paulo%20C%20/Gr%C3%A1fico_de_Dispers%C3%A3o_com_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
#carregando base de dados , encoding= 'unicode_escape'
dataset = pd.read_csv('/content/drive/MyDrive/plano_saude.csv', sep=',', encoding='ISO-8859-1')

# %%
#visualizando
dataset
# Out:
#    Idade  custo  genero fumante tamanho  Unnamed: 5
# 0      0     18     871       M     Sim           1
# 1      1     23    1132       M     Não           2
# 2      2     28    1242       F     Sim           3
# 3      3     33    1356       F     Sim           2
# 4      4     38    1488       M     Não           1
# 5      5     43    1638       F     Não           3
# 6      6     48    2130       M     Não           1
# 7      7     53    2454       F     Sim           2
# 8      8     58    3066       F     Não           3
# 9      9     63    4090       F     Sim           2

# %%
sns.relplot(x='custo', y = 'Idade', data=dataset)

# %%
sns.relplot(x='custo', y = 'Idade', hue='genero', data=dataset)

# %%
sns.relplot(x='custo', y = 'Idade', hue='genero',style='genero', data=dataset)

# %%
sns.relplot(x='custo', y = 'Idade', hue='genero',style='fumante', data=dataset)

# %%
sns.relplot(x='custo', y = 'Idade', hue='tamanho',data=dataset)

# %%
sns.relplot(x='custo', y = 'Idade', size='tamanho', data=dataset)

# %%
sns.relplot(x='custo', y = 'Idade', size='tamanho', sizes=(15,200), data=dataset)
