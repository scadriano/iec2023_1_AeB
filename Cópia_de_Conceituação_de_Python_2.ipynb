# %% [markdown]
# <a href="https://colab.research.google.com/github/anaclaralemosc/iec2023_1_AeB/blob/main/C%C3%B3pia_de_Conceitua%C3%A7%C3%A3o_de_Python_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introdução a Engenharia de Computação

# %%
from platform import python_version
print(f'A versão em uso é´{python_version()}.')
# Out:
# A versão em uso é´3.10.12.

# %%
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %%
import pandas as pd

print('Biblioteca carregada com sucesso!')
# Out:
# Biblioteca carregada com sucesso!

# %%
df_anaclara = pd.read_csv ('/content/drive/MyDrive/hospital (1).txt', sep= ',', index_col=None)

print('Dados importados com sucesso!')
# Out:
# Dados importados com sucesso!

# %%
display(df_anaclara.head())
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0  4201     João     55    M  90.0  Concentradas  38.0           2     SP
# 1  3217    Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 2  4039     Luiz     49    M  92.0    Espalhadas  38.0           2     RS
# 3  1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4  4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
#
#         Time Diagnóstico
# 0  Palmeiras      Doente
# 1   Cruzeiro      Doente
# 2     Grêmio    Saudável
# 3   Atlético      Doente
# 4      Sport    Saudável

# %%
display(df_anaclara)
# Out:
#       Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0   4201     João     55    M  90.0  Concentradas  38.0           2     SP
# 1   3217    Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 2   4039     Luiz     49    M  92.0    Espalhadas  38.0           2     RS
# 3   1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4   4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
# 5   2301      Ana     58    F  94.0  Inexistentes  38.0           3     RJ
# 6   1322    Marta     19    F  87.0    Espalhadas  39.0           3     AM
# 7   3027    Paulo     34    M  67.0     Uniformes  38.4           2     GO
# 8   3546  Roberto     44    M   NaN     Uniformes  37.6           1     PE
# 9   6754   Lorena     33    F  72.0  Inexistentes  38.0           3     RJ
# 10  1735    Pedro     13    M  87.0    Espalhadas   6.0           4     AM
# ...

# %%
df_anaclara = df_anaclara.drop(columns=('Estado','Time'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-597604392bb2> in <cell line: 1>()
# ----> 1 df_anaclara = df_anaclara.drop(columns=('Estado','Time'))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
display(df_anaclara)
# Out:
#       Id     Nome  Idade Sexo  Peso       Manchas  Temp  Internação Estado  \
# 0   4201     João     55    M  90.0  Concentradas  38.0           2     SP
# 1   3217    Maria     56    F  91.0  Inexistentes  39.5           4     MG
# 2   4039     Luiz     49    M  92.0    Espalhadas  38.0           2     RS
# 3   1920     José     57    M  93.0  Inexistentes  38.5           2     MG
# 4   4340  Cláudia     21    F  52.0     Uniformes  37.6           1     PE
# 5   2301      Ana     58    F  94.0  Inexistentes  38.0           3     RJ
# 6   1322    Marta     19    F  87.0    Espalhadas  39.0           3     AM
# 7   3027    Paulo     34    M  67.0     Uniformes  38.4           2     GO
# 8   3546  Roberto     44    M   NaN     Uniformes  37.6           1     PE
# 9   6754   Lorena     33    F  72.0  Inexistentes  38.0           3     RJ
# 10  1735    Pedro     13    M  87.0    Espalhadas   6.0           4     AM
# ...

# %%
df_anaclara.groupby('Diagnóstico').count().plot.pie(y = 'Internação')
# Out:
# <Axes: ylabel='Internação'>

# %%
import matplotlib.pyplot


matplotlib.pyplot.plot(df_anaclara['Temp'])

matplotlib.pyplot.show()

# %%
import seaborn as sns

sns.set_theme()

sns.histplot(df_anaclara['Peso'])
# Out:
# <Axes: xlabel='Peso', ylabel='Count'>
