# %% [markdown]
# <a href="https://colab.research.google.com/github/TerraCampos/iec2023_1_AeB/blob/main/Entregas%20-%20Gustavo%20Terra/Seaborn_Gr%C3%A1fico_de_Dispers%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráficos de dispersão com Seaborn

# %% [markdown]
# ## Importação das bibliotecas

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Carregamento da base de dados

# %%
dataset = pd.read_csv('plano_saude.csv')

# %%
dataset
# Out:
#    idade  custo genero fumante  tamanho
# 0     18    871      M     Sim        1
# 1     23   1132      M     Não        2
# 2     28   1242      F     Sim        3
# 3     33   1356      F     Sim        2
# 4     38   1488      M     Não        1
# 5     43   1638      F     Não        3
# 6     48   2130      M     Não        1
# 7     53   2454      F     Sim        2
# 8     58   3066      F     Não        3
# 9     63   4090      F     Sim        2

# %% [markdown]
# ## Gráficos de dispersão

# %%
sns.relplot(x="custo", y="idade", data=dataset);

# %%
sns.relplot(x="custo", y="idade", hue="genero", data=dataset);

# %%
sns.relplot(x="custo", y="idade", hue="genero", style="genero", data=dataset);

# %%
sns.relplot(x="custo", y="idade", hue="genero", style="fumante", data=dataset);

# %%
sns.relplot(x="custo", y="idade", hue="tamanho", data=dataset);

# %%
sns.relplot(x="custo", y="idade", size="tamanho", data=dataset);

# %%
sns.relplot(x="custo", y="idade", size="tamanho", sizes=(15, 200), data=dataset);
