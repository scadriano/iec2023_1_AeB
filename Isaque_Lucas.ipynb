# %%
from platform import python_version
print(f'A versão em uso é {python_version()}.')
# Out:
# A versão em uso é 3.10.12.

# %%
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %%
import pandas as pd
import matplotlib as mat
import seaborn as sns
print('Biblioteca carregada com sucesso!')
# Out:
# Biblioteca carregada com sucesso!

# %%
df_isaquelucas = pd.read_csv ('https://raw.githubusercontent.com/scadriano/iec2023_1_AeB/main/01.%20Conceitua%C3%A7%C3%A3o%20de%20Python/hospital.csv', sep=',', index_col=None)

# %%
display(df_isaquelucas.head())
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temperatura  Internação  \
# 0  4201     João     28    M    79  Concentradas         38.0           2
# 1  3217    Maria     18    F    67  Inexistentes         39.5           4
# 2  4039     Luiz     49    M    92    Espalhadas         38.0           2
# 3  1920     José     18    M    43  Inexistentes         38.5           8
# 4  4340  Cláudia     21    F    52     Uniformes         37.6           1
#
#   Estado       Time Diagnóstico
# 0     SP  Palmeiras      Doente
# 1     MG   Cruzeiro      Doente
# 2     RS     Grêmio    Saudável
# 3     MG   Atlético      Doente
# 4     PE      Sport    Saudável

# %%
df_isaquelucas = df_isaquelucas.drop(columns=['Estado', 'Time'])

# %%
df_isaquelucas.groupby('Diagnóstico').count().plot.pie(y = 'Internação')
# Out:
# <Axes: ylabel='Internação'>

# %%
sns.set_theme()
sns.histplot(df_isaquelucas['Temperatura'])
# Out:
# <Axes: xlabel='Temperatura', ylabel='Count'>

# %%
display(df_isaquelucas.head())
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temperatura  Internação  \
# 0  4201     João     28    M    79  Concentradas         38.0           2
# 1  3217    Maria     18    F    67  Inexistentes         39.5           4
# 2  4039     Luiz     49    M    92    Espalhadas         38.0           2
# 3  1920     José     18    M    43  Inexistentes         38.5           8
# 4  4340  Cláudia     21    F    52     Uniformes         37.6           1
#
#   Diagnóstico
# 0      Doente
# 1      Doente
# 2    Saudável
# 3      Doente
# 4    Saudável

# %%
dados = pd.read_csv('plano_saude.csv', encoding= 'unicode_escape')

# %%
dados
# Out:
#    Idade  custo genero fumante  tamanho  Unnamed: 5
# 0     18    871      M     Sim        1         NaN
# 1     23   1132      M     No        2         NaN
# 2     28   1242      F     Sim        3         NaN
# 3     33   1356      F     Sim        2         NaN
# 4     38   1488      M     No        1         NaN
# 5     43   1638      F     No        3         NaN
# 6     48   2130      M     No        1         NaN
# 7     53   2454      F     Sim        2         NaN
# 8     58   3066      F     No        3         NaN
# 9     63   4090      F     Sim        2         NaN

# %%
sns.relplot(x="custo", y="Idade", data=dados);

# %%
sns.relplot(x="custo", y="Idade", hue="genero", data=dados);

# %%
sns.relplot(x="custo", y="Idade", hue="genero", style="genero", data=dados);

# %%
sns.relplot(x="custo", y="Idade", hue="genero", style="fumante", data=dados);
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 139 (\x8b) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 139 (\x8b) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 139 (\x8b) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.relplot(x="custo", y="Idade", hue="tamanho", data=dados);

# %%
sns.relplot(x="custo", y="Idade", size="tamanho", data=dados);

# %%
sns.relplot(x="custo", y="Idade", size="tamanho", sizes=(15, 200), data=dados);
