# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrocsf/iec2023_1_AeB/blob/main/Entregas%20PedroF/IEC_05_07_Seaborn_Gr%C3%A1fico_de_Dispers%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Atividade 05/07/2023 - IEC**

# %% [markdown]
# Gráfico de Dispersão com *Seaborn*

# %% [markdown]
# Importando bibliotecas

# %%
import pandas
import seaborn

# %% [markdown]
# Subindo banco de dados

# %%
try:
    dataset = pandas.read_csv('/content/plano_saude.csv', encoding='utf-8')
except UnicodeDecodeError as e:
    print(f"Erro de decodificação: {e}\n")
    print(f"Tendo em vista o erro de codificação gerado pelo caractere ã,\nfiz a correção do dataset e o arquivo novo se chama 'plano_saude_CORRIGIDO.csv ")

dataset = pandas.read_csv('plano_saude_CORRIGIDO.csv')
# Out:
# Erro de decodificação: 'utf-8' codec can't decode byte 0xe3 in position 1: invalid continuation byte
#
# Tendo em vista o erro de codificação gerado pelo caractere ã,
# fiz a correção do dataset e o arquivo novo se chama 'plano_saude_CORRIGIDO.csv

# %% [markdown]
# Exibição do banco de dados

# %%
dataset
# Out:
#    idade  custo  genero fumante tamanho  Unnamed: 5
# 0      0     18     871       M     Sim           1
# 1      1     23    1132       M     Nao           2
# 2      2     28    1242       F     Sim           3
# 3      3     33    1356       F     Sim           2
# 4      4     38    1488       M     Nao           1
# 5      5     43    1638       F     Nao           3
# 6      6     48    2130       M     Nao           1
# 7      7     53    2454       F     Sim           2
# 8      8     58    3066       F     Nao           3
# 9      9     63    4090       F     Sim           2

# %% [markdown]
# Gráficos de dispersão

# %%
    seaborn.relplot(x="custo", y="idade", data=dataset);
    print(f"Tendo em vista um novo erro de codificação gerado pelo caractere I (maiúsculo),\nfiz a correção do dataset atual")
# Out:
# Tendo em vista um novo erro de codificação gerado pelo caractere I (maiúsculo),
# fiz a correção do dataset atual

# %%
seaborn.relplot(x="custo", y="idade", hue="genero", data=dataset);

# %%
seaborn.relplot(x="custo", y="idade", hue="genero", style="genero", data=dataset);

# %%
seaborn.relplot(x="custo", y="idade", hue="genero", style="fumante", data=dataset);

# %%
seaborn.relplot(x="custo", y="idade", hue="tamanho", data=dataset);

# %%
seaborn.relplot(x="custo", y="idade", size="tamanho", data=dataset);
