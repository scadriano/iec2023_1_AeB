# %% [markdown]
# # **Introdução** **à** **Engenharia** **de** **Computação**

# %%
from platform import python_version
print(f'A versão em uso é {python_version()}.')
# Out:
# A versão em uso é 3.10.12.

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %% [markdown]
# # **Operadores Aritiméticos**

# %%
# Adição
1 + 1
# Out:
# 2

# %%
# Subtração
2 + 1

# %%
# Multiplicação
3 * 2
# Out:
# 6

# %%
# Divisão
4 / 2
# Out:
# 2.0

# %%
# Potência
2 ** 2
# Out:
# 4

# %%
# Módulo (resto da divisão)
10 % 3
# Out:
# 1

# %% [markdown]
# # **Tipos de Dados**

# %%
# Qual o tipo do (?) -> Inteiro
type(5)
# Out:
# int

# %%
# Qual o tipo do (?) -> Decimal
type(5.0)
# Out:
# float

# %%
# Qual o tipo do (?) -> String
a = 'estudando python'
type(a)
# Out:
# str

# %% [markdown]
# #**Condicional if**

# %%
# Condicional if (Se)
if 5 > 2:
  print("A sentença é verdadeira")
# Out:
# A sentença é verdadeira

# %%
# Condicional if...else
if 5 < 2:
  print("A sentença é verdadeira")
else:
  print("A sentença é falsa")
# Out:
# A sentença é falsa

# %%
# Condicional if..else com variável
dia = "Quarta-feira"
if dia == "Sexta-feira":
  print("Hoje fará sol!")
else:
  print("Hoje vai chover!")
# Out:
# Hoje vai chover!

# %% [markdown]
# #**Manipulando Arquivos**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Lendo Arquivos (.txt)**

# %%
# Abrindo o arquivo para leitura
a1 = open("/content/drive/MyDrive/Colab Notebooks/Arquivo de Leitura.txt", "r")

# %%
# Lendo o arquivo
print(a1.read())
# Out:
# ﻿Engenharia de Computação

# %% [markdown]
# **Gravando Arquivos (.txt)**

# %%
# Abrindo o arquivo para gravação
a2 = open("/content/drive/MyDrive/Colab Notebooks/Arquivo para Gravação.txt", "w")

# %%
# Gravando no arquivo
a2.write("Arraial do Engenho - 2023!")
# Out:
# 26

# %%
# Abrindo o arquivo para leitura
a2 = open("/content/drive/MyDrive/Colab Notebooks/Arquivo para Gravação.txt", "r")

# %%
# Imprimindo arquivo
print(a2.read())
# Out:
# Arraial do Engenho - 2023!Arraial do Engenho - 2023!
