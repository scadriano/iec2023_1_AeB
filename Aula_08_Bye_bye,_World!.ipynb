# %% [markdown]
# <a href="https://colab.research.google.com/github/ian29ac/iec2023_1_AeB/blob/main/Aula_08_Bye_bye%2C_World!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Introdução à Engenharia de Computação ##

# %%
from platform import python_version
print(f'A versão em uso é (python_version()).')
# Out:
# A versão em uso é (python_version()).

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %%
# Adição
1+1
# Out:
# 2

# %%
# Subtração
2-1
# Out:
# 1

# %%
# Multiplicação
2 * 2
# Out:
# 4

# %%
# Divisão
3 / 2
# Out:
# 1.5

# %%
# Potência
4 ** 2
# Out:
# 16

# %%
# Módulo (resto da divisão)
10 % 3
# Out:
# 1

# %% [markdown]
# Tipos de Dados

# %%
# Qual o tipo do (?) -> Inteiro
type(5)
# Out:
# int

# %%
# Qual o tipo do (?) -> float
type(1.5)
# Out:
# float

# %%
# Qual o tipo do (?) -> str
type("Estudando Python")
# Out:
# str

# %% [markdown]
# Condicionais

# %%
if 5>2:
  print("A sentença é verdadeira!")
else:
  print("A sentença é falsa!")
# Out:
# A sentença é verdadeira!

# %%
dia = "Quarta-Feira"
if dia == "Sexta-Feira":
  print("Hoje fará sol")
else:
  print("Hoje vai chover")
type(dia)
# Out:
# Hoje vai chover
# str

# %% [markdown]
# Lendo Arquivos

# %%
from google.colab import drive
a1 = open("/content/drive/MyDrive/Colab Notebooks/confidencial.txt","r")

# %%
print(a1.read())
# Out:
# aprender python

# %%
a2 = open("/content/drive/MyDrive/Colab Notebooks/Aula 08 - Bye bye, World!.ipynb","w")

# %%
a2.write("Aprendendo Python!")
# Out:
# 18

# %%
a2 = open("/content/drive/MyDrive/Colab Notebooks/Aula 08 - Bye bye, World!.ipynb","r")

# %%
print(a2.read())
# Out:
# Aprendendo Python!
