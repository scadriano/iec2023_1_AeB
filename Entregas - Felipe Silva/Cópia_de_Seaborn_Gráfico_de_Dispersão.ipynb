# %% [markdown]
# <a href="https://colab.research.google.com/github/Flipe41/iec2023_1_AeB/blob/main/Entregas%20-%20Felipe%20Silva/C%C3%B3pia_de_Seaborn_Gr%C3%A1fico_de_Dispers%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráficos de dispersão com Seaborn

# %% [markdown]
# ## Importação das bibliotecas

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Carregamento da base de dados

# %%
dataset = pd.read_csv('/content/plano_saude.csv')

# %%
dataset
# Out:
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1728033318150323379 = autoviz.get_registered_df('df_1728033318150323379')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1728033318150323379, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3256553698330933932 = autoviz.get_registered_df('df_3256553698330933932')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_3256553698330933932, *['Idade'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_9201191664566258458 = autoviz.get_registered_df('df_9201191664566258458')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_9201191664566258458, *['custo'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5634161342666481884 = autoviz.get_registered_df('df_5634161342666481884')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_5634161342666481884, *['tamanho'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3008550287467359393 = autoviz.get_registered_df('df_3008550287467359393')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3008550287467359393, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7703122887633995622 = autoviz.get_registered_df('df_7703122887633995622')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_7703122887633995622, *['Idade'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4496826928187251816 = autoviz.get_registered_df('df_4496826928187251816')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_4496826928187251816, *['custo'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2927473795299781182 = autoviz.get_registered_df('df_2927473795299781182')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2927473795299781182, *['tamanho'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_768287469318119548 = autoviz.get_registered_df('df_768287469318119548')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_768287469318119548, *['genero'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_92359837221023577 = autoviz.get_registered_df('df_92359837221023577')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_92359837221023577, *['fumante'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5602599624330233665 = autoviz.get_registered_df('df_5602599624330233665')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_5602599624330233665, *[[['index', 'Idade'], ['Idade', 'custo'], ['custo', 'tamanho']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2718805943203783025 = autoviz.get_registered_df('df_2718805943203783025')
#
# def heatmap(df, x_colname, y_colname, figsize=(2, 2)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=figsize)
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=sns.cubehelix_palette(start=.5, rot=-.8))
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(df_2718805943203783025, *['genero', 'fumante'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8306950835282867655 = autoviz.get_registered_df('df_8306950835282867655')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_8306950835282867655, *['index', 'genero'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7226321503133892916 = autoviz.get_registered_df('df_7226321503133892916')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_7226321503133892916, *['index', 'fumante'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2265792896186133912 = autoviz.get_registered_df('df_2265792896186133912')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_2265792896186133912, *['Idade', 'genero'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6938092260572175261 = autoviz.get_registered_df('df_6938092260572175261')
#
# def violin_plot(df, value_colname, facet_colname, col_width=.3, col_length=3, **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   plt.figure(figsize=(col_length, col_width * len(df[facet_colname].unique())))
#   sns.violinplot(df, x=value_colname, y=facet_colname, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(df_6938092260572175261, *['Idade', 'fumante'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2277591420326235292 = autoviz.get_registered_df('df_2277591420326235292')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_2277591420326235292, *['index', 'tamanho', 'genero'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6187149847037541163 = autoviz.get_registered_df('df_6187149847037541163')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_6187149847037541163, *['index', 'tamanho', 'fumante'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_9110756824115939976 = autoviz.get_registered_df('df_9110756824115939976')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_9110756824115939976, *['index', 'count()', 'genero'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5074109798321653622 = autoviz.get_registered_df('df_5074109798321653622')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3)):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   def _plot_series(series, series_name):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name)
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for series_name, series in df.groupby(series_colname):
#       _plot_series(series, series_name)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_5074109798321653622, *['index', 'count()', 'fumante'], **{})
# chart
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
#    Idade  custo genero fumante  tamanho  Unnamed: 5
# 0     18    871      M     Sim        1         NaN
# 1     23   1132      M     Nao        2         NaN
# 2     28   1242      F     Sim        3         NaN
# 3     33   1356      F     Sim        2         NaN
# 4     38   1488      M     Nao        1         NaN
# 5     43   1638      F     Nao        3         NaN
# 6     48   2130      M     Nao        1         NaN
# 7     53   2454      F     Sim        2         NaN
# 8     58   3066      F     Nao        3         NaN
# 9     63   4090      F     Sim        2         NaN

# %% [markdown]
# ## Gráficos de dispersão

# %%
sns.relplot(x="custo", y="Idade", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", hue="genero", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", hue="genero", style="genero", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", hue="genero", style="fumante", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", hue="tamanho", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", size="tamanho", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", size="tamanho", sizes=(15, 200), data=dataset);
